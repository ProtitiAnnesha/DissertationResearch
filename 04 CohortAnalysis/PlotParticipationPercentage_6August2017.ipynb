# %%
import numpy as np
import matplotlib.pyplot as plt

# You can read write or append
# The first line open the file with the intention of reading it
# readFile.read

readFile = open('C:\\Users\\ane13003\\OneDrive - University of Connecticut\\CohortAnalysis\\PythonPlots_Backup_2015\\PartPer_08_06_2017.txt','r')
sepFile = readFile.read().split('\n')
readFile.close()
# Will print the elements as strings
#print sepFile

# This variable will read duration for one age group
dur = np.empty((0,6),int) #Read the whole file into an array

for i in sepFile: # Read each line of the file
    line = i.split(',') # Split the lines at the comma 
    #print line
    ls = []
    for j in range(0,6):
        ls.append(int(line[j])) #Append all the values of the line into a list
    #print ls
    dur = np.append(dur, np.array([ls]), axis=0) #Add the list into the duration array #Adds one line at a time to the duration array
#print dur     
# END OF READING THE DATA

# DEFINITION OF SOME VARIABLES
cohorts = 5
AgeGroup = 6
width = 0.18
# END OF DEFINITION OF THE VARIABLES

# This command creates the figure and axis in the same go
# ax is an no array, with 1 row and 2 columns
# Also you can pass parameters to tell it to share the y and the x axis
# f is the figure object, ax is a 1 by 2 array which is essentialy a row vector in this case
f,ax = plt.subplots(AgeGroup,1, sharey = True, sharex = True, figsize = (10,10)) # The first number is the number of rows and 2nd number is the number of columns

# THIS SETS THE FONT SIZE FOR THE Y AXIS
axis_font = {'family' : 'cambria',
        'weight' : 'bold',
        'size'   : 16}

f.text(0.02, 0.53, 'Paricipation in Percentages (%)', va='center', rotation='vertical', **axis_font) # This is the common y-label for all the subplots
f.set_size_inches(9,6)  # This sets the figure size to be 9 inch by 6 inch

# Adjusting are for the subplot
plt.subplots_adjust(left=0.05, right=0.97, top=0.95, bottom=0.10, hspace = 0.35) # hspace increases the space between the subplots

# Provide x tick lables
ind = np.arange(6)
ax[0].set_xticks(ind+width*2)
ax[0].set_xticklabels( ('MOH', 'DIH', 'DOH', 'Work', 'Education', 'Travel') )

# Setting y-limit on the axes
ax[0].set_ylim([0,120])

# Make the y axis labels invisible
for i in range(0,AgeGroup):
    ax[i].yaxis.set_visible(False)

# Change the font size for all elements
font = {'family' : 'cambria',
        'weight' : 'bold',
        'size'   : 10}

# Setting the font
plt.rc('font', **font)

# END OF PLOT BBEAUTIFICATION


# THE MAIN FUNCTION THAT WILL CREATE THE PLOT
def create_subplot(matrix, colors, axis, title):
    bar_rend = [] # Define an empty list
    # ind is the x location of the vertical bars
    # Defined by how many columns are there in the matrix
    ind = np.arange(matrix.shape[1]) # get the column number of the passed matrix
    for i, row in enumerate(matrix):
        #print('row',row)
        r = axis.bar(ind+width*i,row, width, color = colors[i])
        #print type(r)
        bar_rend.append(r)
    axis.set_title(title)
    return bar_rend
# END OF THE MAIN FUNCTION

p = [] # An empty list to hold bar properties

# CALLING THE FUNCTION TO CREATE THE PLOT
# Defining the colosrs as a list #Colors and Labels would be same for all the age groups
c_1_colors = ['yellow','green','blue','orange', 'red']
sub_title = ['Age group 18 to 24','Age group 25 to 34','Age group 35 to 44','Age group 45 to 54','Age group 55 to 64','Age group 65 and above'  ]
dum = 0
for i in range(0,AgeGroup):
    c_1 = dur[dum:(dum+cohorts),]
    #print('i',c_1)
    p.extend(create_subplot(c_1, c_1_colors, ax[i],sub_title[i]))
    dum = dum + cohorts
# END OF CALL



# CREATING LABELS    
c_1_labels = ['GI Generation', 'Silent Generation', 'Baby Boomer', 'Generation X', 'Millennial']    
    
f.legend(((x[0] for x in p)), # bar properties
        (c_1_labels ), 
         bbox_to_anchor=(0.50, 0), 
         loc='lower center', 
         ncol=5)
# END OF LABEL CREATION


# PROVIDE TEXT TO THE PLOT
def autolabel(rects, i):
    # attach some text labels
    for rect in rects:
        #print('rect', rect)
        height = rect.get_height()
        #print('height', height)
        if height > 1:
            ax[i].text(rect.get_x()+rect.get_width()/2., 1.00*height, '%d'%int(height),
                ha='center', va='bottom', **font)

for i in range(0,29):
    #print('i',i)
    autolabel(p[i], i/5) #The last argument is the pointer to the axis, here we are doing an integer division
# END OF PROVIDING TEXT TO THE PLOT

#plt.show()

f.savefig('C:\\Users\\ane13003\\OneDrive - University of Connecticut\\CohortAnalysis\\PythonPlots_Backup_2015\\part_per_08_06_2017.tif',dpi=300)
